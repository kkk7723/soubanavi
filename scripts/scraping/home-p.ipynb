# %%
import os
import re
import sqlite3
import sys
import time

from datetime import datetime
from urllib.parse import urljoin

import requests

from bs4 import BeautifulSoup


# ==================================================
# importパス設定
# ==================================================

# Jupyter・通常のPythonスクリプトの両方に対応
try:
    base_dir = os.path.dirname(
        os.path.abspath(__file__)
    )
except NameError:
    base_dir = os.getcwd()


project_root = os.path.abspath(
    os.path.join(
        base_dir,
        "..",
        "..",
    )
)


if project_root not in sys.path:
    sys.path.insert(
        0,
        project_root,
    )


from utils.config import (
    DB_PATH,
    PROXY_LIST,
    PROXY_MODE,
    PROXY_ROTATE_EVERY,
)


# ==================================================
# 初期設定
# ==================================================

start_time = time.time()

table_name = "result_table"


# ==================
# スクレイピングサイト設定
# ==================

SHOP_NAME = (
    "安心・安全・高品質の中古パチスロ・"
    "中古パチンコ実機販売店【ホームスロット】"
)

SHOP_PRODUCT_ID = 2
CATEGORY = "pachi"

BASE_URL = (
    "https://home-slot.net/"
    "SHOP/191465/t01/list{}.html"
)

MAX_PAGE = 100

# ページ間の待機秒数
REQUEST_INTERVAL = 10

# 1回のリクエストのタイムアウト秒数
REQUEST_TIMEOUT = 120

# 1ページあたりの最大試行回数
MAX_RETRIES = 5

# リトライまでの待機秒数
RETRY_INTERVAL = 30


# ==================
# プロキシ
# ==================

def _resolve_proxy_for_batch(
    batch_index: int,
) -> str | None:

    mode = (
        PROXY_MODE or "none"
    ).strip().lower()

    if mode == "none":
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    if mode != "list":

        raw = (
            PROXY_MODE or ""
        ).strip()

        if raw.lower() == "none" or raw == "":
            print(
                f"[INFO] Proxy for batch {batch_index}: "
                "(none直結)"
            )
            return None

        proxy = (
            raw
            if "://" in raw
            else f"http://{raw}"
        )

        print(
            f"[INFO] Proxy for batch {batch_index}: "
            f"{proxy}"
        )

        return proxy

    if not PROXY_LIST:
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    step = max(
        1,
        int(PROXY_ROTATE_EVERY or 1),
    )

    idx = (
        batch_index // step
    ) % len(PROXY_LIST)

    pick = str(
        PROXY_LIST[idx]
    ).strip()

    if pick.lower() == "none" or pick == "":
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    proxy = (
        pick
        if "://" in pick
        else f"http://{pick}"
    )

    print(
        f"[INFO] Proxy for batch {batch_index}: "
        f"{proxy}"
    )

    return proxy


def open_session(
    batch_index: int = 0,
) -> requests.Session:

    proxy = _resolve_proxy_for_batch(
        batch_index
    )

    session = requests.Session()

    session.headers.update({
        "User-Agent": (
            "Mozilla/5.0 "
            "(Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 "
            "(KHTML, like Gecko) "
            "Chrome/138.0.0.0 "
            "Safari/537.36"
        )
    })

    if proxy:
        session.proxies = {
            "http": proxy,
            "https": proxy,
        }

    return session


# ==================
# ページ取得・リトライ
# ==================

def get_page(
    session: requests.Session,
    url: str,
) -> requests.Response | None:

    for retry_count in range(
        1,
        MAX_RETRIES + 1,
    ):

        try:
            print(
                f"[REQUEST] 取得開始 "
                f"({retry_count}/{MAX_RETRIES})"
            )

            response = session.get(
                url,
                timeout=REQUEST_TIMEOUT,
            )

            if response.status_code == 200:
                return response

            print(
                f"[ERROR] HTTP "
                f"{response.status_code} "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ReadTimeout:
            print(
                f"[ERROR] 読み込みタイムアウト "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ConnectTimeout:
            print(
                f"[ERROR] 接続タイムアウト "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ConnectionError as e:
            print(
                f"[ERROR] 接続エラー "
                f"({retry_count}/{MAX_RETRIES}): {e}"
            )

        except requests.RequestException as e:
            print(
                f"[ERROR] リクエストエラー "
                f"({retry_count}/{MAX_RETRIES}): {e}"
            )

        # 最終試行でなければ待機して再試行
        if retry_count < MAX_RETRIES:
            print(
                f"[RETRY] {RETRY_INTERVAL}秒後に"
                "同じページを再試行します"
            )

            time.sleep(
                RETRY_INTERVAL
            )

    print(
        f"[ERROR] {MAX_RETRIES}回取得に失敗しました"
    )

    return None


# ==================
# DB
# ==================

def save_product(
    data: dict,
) -> None:

    conn = sqlite3.connect(
        DB_PATH
    )

    try:
        cur = conn.cursor()

        sql = f"""
        INSERT INTO {table_name}
        (
            shop_name,
            shop_product_id,
            category,
            machine_name,
            product_url,
            image_url,
            price,
            created_at
        )
        VALUES
        (?, ?, ?, ?, ?, ?, ?, ?)
        """

        cur.execute(
            sql,
            (
                SHOP_NAME,
                SHOP_PRODUCT_ID,
                CATEGORY,
                data["machine_name"],
                data["product_url"],
                data["image_url"],
                data["price"],
                datetime.now(),
            ),
        )

        conn.commit()

    except Exception:
        conn.rollback()
        raise

    finally:
        conn.close()


# ==================
# スクレイピング開始
# ==================

session = open_session()
total_count = 0


try:

    # ==================
    # ページループ
    # ==================

    for page in range(
        1,
        MAX_PAGE + 1,
    ):

        url = BASE_URL.format(
            page
        )

        print(
            f"\n{'=' * 80}"
        )
        print(
            f"Page {page}"
        )
        print(
            url
        )

        # --------------------------
        # ページ取得
        # --------------------------

        response = get_page(
            session,
            url,
        )

        if response is None:
            print(
                f"[ERROR] Page {page}の取得に"
                "失敗したため終了します"
            )
            break

        # 文字コードを自動判定
        response.encoding = (
            response.apparent_encoding
        )

        soup = BeautifulSoup(
            response.text,
            "html.parser",
        )

        item_list = soup.find(
            "div",
            id="itemList",
        )

        if item_list is None:
            print(
                "[ERROR] itemListが見つかりません"
            )
            break

        # 商品一覧
        # 1商品 = section.column4
        products = item_list.select(
            "section.column4"
        )

        found_count = len(
            products
        )

        saved_count = 0

        for product in products:

            # --------------------------
            # タイトル・商品URL
            # --------------------------

            a = product.select_one(
                "h2 > a"
            )

            if a is None:
                continue

            machine_name = a.get_text(
                " ",
                strip=True,
            )

            href = str(
                a.get(
                    "href",
                    "",
                )
                or ""
            ).strip()

            if not machine_name:
                print(
                    "[SKIP] 商品名が空です"
                )
                continue

            if not href:
                print(
                    f"[SKIP] 商品URLが空です: "
                    f"{machine_name}"
                )
                continue

            product_url = urljoin(
                url,
                href,
            )

            # --------------------------
            # 画像URL
            # --------------------------

            image_url = ""

            img = product.select_one(
                "span.item-list-span-img img"
            )

            if img:

                image_src = (
                    img.get("src")
                    or img.get("data-src")
                    or img.get("data-original")
                    or img.get("data-lazy-src")
                    or ""
                )

                if image_src:
                    image_url = urljoin(
                        url,
                        image_src,
                    )

            # --------------------------
            # 価格
            # --------------------------

            price = ""

            price_tag = product.select_one(
                "span.selling_price"
            )

            if price_tag:

                price_text = price_tag.get_text(
                    strip=True
                )

                price = re.sub(
                    r"[^\d]",
                    "",
                    price_text,
                )

            # --------------------------
            # 表示
            # --------------------------

            print(
                "-" * 80
            )
            print(
                "ショップ:",
                SHOP_NAME,
            )
            print(
                "カテゴリ:",
                CATEGORY,
            )
            print(
                "機種名  :",
                machine_name,
            )
            print(
                "商品URL :",
                product_url,
            )
            print(
                "画像URL :",
                image_url,
            )
            print(
                "価格    :",
                price,
            )

            # --------------------------
            # DB保存
            # --------------------------

            try:
                save_product({
                    "machine_name": machine_name,
                    "product_url": product_url,
                    "image_url": image_url,
                    "price": price,
                })

                print(
                    "[DB] 保存完了"
                )

            except sqlite3.Error as e:
                print(
                    f"[DB ERROR] 保存失敗: {e}"
                )
                continue

            saved_count += 1
            total_count += 1

        print(
            f"\nページ検出件数 : {found_count}"
        )
        print(
            f"ページ保存件数 : {saved_count}"
        )

        # 商品が無くなったら終了
        if found_count == 0:
            print(
                "商品がありません。終了します。"
            )
            break

        # 次のページへ進む前に待機
        if page < MAX_PAGE:
            print(
                f"[WAIT] 次のページまで"
                f"{REQUEST_INTERVAL}秒待機します"
            )

            time.sleep(
                REQUEST_INTERVAL
            )


finally:

    # ==================
    # 終了
    # ==================

    session.close()


# ==================
# 結果表示
# ==================

print(
    "\n" + "=" * 80
)
print(
    f"総取得件数 : {total_count}"
)
print(
    "=" * 80
)

end_time = time.time()

print(
    "[INFO] スクリプト完了"
    f"（実行時間: "
    f"{end_time - start_time:.2f} 秒）"
)
# Out:
# [INFO] Proxy for batch 0: (none直結)
#
# ================================================================================
# Page 1
# https://home-slot.net/SHOP/191465/t01/list1.html
# [REQUEST] 取得開始 (1/5)
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 平和 eガールズ＆パンツァー 最終章 159ver. 中古パチンコ実機 [スマパチ]　[枠名：BLAST　eガールズ＆パンツァー3LBH7]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-heiwa253.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_girlspanzer159.jpg?t=20260630181157
# 価格    : 335200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : サンセイ e結城友奈は勇者である～極限7500～ 中古パチンコ実機 [スマパチ]　[枠名：eV-LIGHT　e結城友奈は勇者であるMP]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sansei267.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_yukiyusya7500.jpg?t=20260630165857
# 価格    : 349100
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : メーシー e冥妃転生 中古パチンコ実機 [スマパチ]　[枠名：ディアマンテ]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-macy239.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_meihitense.jpg?t=20260606223705
# 価格    : 191300
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 大都技研 e ソードアート・オンライン オルタナティブ ガンゲイル・オンライン 中古パチンコ実機 [スマパチ]　[枠名：グラフィカ　ガンゲイル・オンライン]
# 商品URL : https://home-slot.net/SHOP/p-daito217.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_sao_gungale.jpg?t=20260606120215
# 価格    : 221200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : SANYO PAスーパー海物語IN沖縄6 Withえなこ 中古パチンコ実機　[枠名：ラッキーシェル]　[2ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sanyo264.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/pa_spumi6enako.jpg?t=20260603133235
# 価格    : 724600
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 豊丸 遊moreLT PエガブレイブVVV 枠不問 中古パチンコ実機
# 商品URL : https://home-slot.net/SHOP/p-toyomaru260.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/morelt_ega__vvv.jpg?t=20260603131241
# 価格    : 165900
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : D-light P 犬夜叉3.0 大入り 甘SPEC 中古パチンコ実機　[枠名：Cygnus]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-dlight244.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/inuyasya3_amaspec.jpg?t=20260521195937
# 価格    : 266100
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : SANKYO PフィーバークィーンII 2026 中古パチンコ実機　[枠名：フリーダム]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sankyo311.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/p_fvqueen2_2026.jpg?t=20260506163326
# 価格    : 404400
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 七匠 e バイオハザード6 中古パチンコ実機 [スマパチ]　[枠名：スピネル]
# 商品URL : https://home-slot.net/SHOP/p-nanashow206.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_biohazard6.jpg?t=20260505200105
# 価格    : 165900
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : D-light eカケグルイ 7500ver. 中古パチンコ実機 [スマパチ]　[枠名：Cygnus+]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-dlight243.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_kakegurui7500.jpg?t=20260509170323
# 価格    : 197600
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : アムテックス eルパン三世VSキャッツ・アイ157ver. 極限突破ブッた斬り7500 中古パチンコ実機 [スマパチ]　[枠名：Neo-Peace]
# 商品URL : https://home-slot.net/SHOP/p-amutex254.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_lupin_catseye157.jpg?t=20260505154037
# 価格    : 206200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : SanThree eまわるん超ワープ ギンギラパラダイス VIVA FESTA 中古パチンコ実機 [スマパチ]　[枠名：マルチフレーム]
# 商品URL : https://home-slot.net/SHOP/p-santhree225.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_ginpara_vivafes.jpg?t=20260505144343
# 価格    : 197600
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 京楽 e ライザのアトリエ ～常闇の女王と秘密の隠れ家～ 中古パチンコ実機 [スマパチ]　[枠名：ｅベルーガ　ｅライザのアトリエK3]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-kyoraku250.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_raiza_atelier.jpg?t=20260505123625
# 価格    : 162300
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : メーシー eラグナドール 妖しき皇帝と終焉の夜叉姫 中古パチンコ実機 [スマパチ]　[枠名：ディアマンテ]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-macy238.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_ragnador.jpg?t=20260423230713
# 価格    : 111000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : SANKYO e フィーバーキン肉マン 中古パチンコ実機 [スマパチ]　[枠名：JB eフリーダム　キン肉マン]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sankyo310.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_kinnikuman.jpg?t=20260417151546
# 価格    : 221200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : アムテックス e86-エイティシックス- 中古パチンコ実機 [スマパチ]　[枠名：Neo-Peace]
# 商品URL : https://home-slot.net/SHOP/p-amutex253.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e86.jpg?t=20260417143543
# 価格    : 418200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : オレンジ e リング 最恐領域 中古パチンコ実機 [スマパチ]　[枠名：バーサタイル　リング 最恐領域RHA]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-orange204.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_ring_saikyo.jpg?t=20260417141149
# 価格    : 266100
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : タイヨーエレック e 終末のワルキューレ 中古パチンコ実機 [スマパチ]　[枠名：誓]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-taiyo201.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_walkyure.jpg?t=20260403161447
# 価格    : 106000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : サンセイ e転生したらスライムだった件2 中古パチンコ実機 [スマパチ]　[枠名：eV-LIGHT　転生したらスライムだった件２ＭＦ]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sansei266.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_tensura2.jpg?t=20260402144733
# 価格    : 221200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : オッケー. P ウルトラマンメビウス デカヘソ319 中古パチンコ実機　[枠名：ベルーガ　ウルトラマンメビウスＭ４]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-ok223.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/p_ultramevius_deka319.jpg?t=20260401210228
# 価格    : 129000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : ニューギン eリコリス・リコイル 中古パチンコ実機 [スマパチ]　[枠名：LEUKOS]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-newgin321.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_lycoreco.jpg?t=20260401203947
# 価格    : 914700
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : メーシー P沖ドキ！ドキドキ弾丸ツアー 中古パチンコ実機　[枠名：SHINOBI7　P沖ドキ!LG]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-macy237.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/okidoki_dangan.jpg?t=20260317231031
# 価格    : 127300
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : メーシー Pえとたま2 神祭 干支甘 中古パチンコ実機　[枠名：SHINOBI7　えとたま2SE]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-macy236.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/p_etotama2eto.jpg?t=20260317140141
# 価格    : 141000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 竹屋 PキングモンスターRUSH 67Ver. 中古パチンコ実機　[枠名：SWGT]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-takeya207.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/kingmonster67.jpg?t=20260312222440
# 価格    : 488500
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 七匠 スマパチ SSSS.GRIDMAN メガSTART 159ver. 中古パチンコ実機 [スマパチ]　[枠名：七匠Cygnus　グリッドマンBDN]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-nanashow205.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/s_ssss_gridman159.jpg?t=20260312154543
# 価格    : 91000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 京楽 e 乃木坂46 II SWEET Version 中古パチンコ実機 [スマパチ]　[枠名：新枠　e 乃木坂46 II SWEET version]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-kyoraku249.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_nogizaka46_2sweet.jpg?t=20260312151819
# 価格    : 206200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 銀座 e 甲鉄城のカバネリ2 咲かせや燦然 中古パチンコ実機 [スマパチ]　[枠名：誓]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-ginza233.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_kabaneri2sakase.jpg?t=20260228231255
# 価格    : 92400
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : SANKYO eフィーバーダンベル何キロ持てる？2 中古パチンコ実機 [スマパチ]　[枠名：JB eフリーダム　ダンベル何キロ持てる]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sankyo309.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_fvdumbbell2.jpg?t=20260225134447
# 価格    : 216200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : SANYO eアクダマドライブ 中古パチンコ実機 [スマパチ]　[枠名：マルチフレーム]
# 商品URL : https://home-slot.net/SHOP/p-sanyo263.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_akudamadrive.jpg?t=20260224200221
# 価格    : 196300
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 京楽 e 魔法少女まどか☆マギカ3 時間遡行～始まりの願い～ 中古パチンコ実機 [スマパチ]　[枠名：ｅベルーガ　まどマギ3LPM1]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-kyoraku248.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_madomagi3time.jpg?t=20260224192839
# 価格    : 226200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : サンセイ e牙狼11～冴島大河～魔戒BURST Ver. 中古パチンコ実機 [スマパチ]　[枠名：V-LIGHT　e牙狼RF]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sansei265.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/gro11burst.jpg?t=20260224175633
# 価格    : 155900
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : ニューギン eワンパンマン2～正義執行 中古パチンコ実機 [スマパチ]　[枠名：LEUKOS]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-newgin320.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/onepunchman2seigi.jpg?t=20260224173853
# 価格    : 266100
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 藤商事 P痛いのは嫌なので防御力に極振りしたいと思います。 極振り129ver 中古パチンコ実機　[枠名：クリスタルエアー　P防振り 極振り129verFVZ]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-fuji258.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/p_boufuri_kyoku129v.jpg?t=20260223175348
# 価格    : 211200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : アムテックス P戦国乙女7 終焉の関ヶ原 99ver. 中古パチンコ実機　[枠名：BLAST　Ｐ戦国乙女7L0YU1]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-amutex252.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/p_senoto7_99v.jpg?t=20260223173644
# 価格    : 464700
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 大都技研 P Re：ゼロから始める異世界生活 season2 249ver. 中古パチンコ実機　[枠名：グラフィカ　Re:ゼロから始める異世界生活season2/M04]
# 商品URL : https://home-slot.net/SHOP/p-daito216.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/rezero2_249.jpg?t=20260223155438
# 価格    : 173600
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 大都技研 P Re：ゼロから始める異世界生活 season2 129ver. 中古パチンコ実機　[枠名：グラフィカ　Re:ゼロから始める異世界生活season2/A10]
# 商品URL : https://home-slot.net/SHOP/p-daito215.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/rezero2_129v.jpg?t=20260223153706
# 価格    : 357900
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : サミー e 真・北斗無双 第5章 夢幻闘双 中古パチンコ実機 [スマパチ]　[枠名：誓]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sammy249.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_hokuto5_mugen.jpg?t=20260129155441
# 価格    : 97400
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : SANKYO eフィーバーBASTARD!! -暗黒の破壊神- 中古パチンコ実機 [スマパチ]　[枠名：JB eフリーダム　ｅフィーバーバスタードＧ]　[4ch対応]
# 商品URL : https://home-slot.net/SHOP/p-sankyo308.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/ef_bastard.jpg?t=20260129145840
# 価格    : 97400
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 藤商事 e異世界でチート能力を手にした俺は現実世界をも無双する ～レベルアップは人生を変えた～ 中古パチンコ実機 [スマパチ]　[枠名：NEWバーサタイル　ｅいせれべＦＳＺ]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-fuji257.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/e_iseleve.jpg?t=20260129135225
# 価格    : 126000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 安心・安全・高品質の中古パチスロ・中古パチンコ実機販売店【ホームスロット】
# カテゴリ: pachi
# 機種名  : 平和 P黄門ちゃま寿限無 LLサイズ 259ver. 中古パチンコ実機　[枠名：BLAST　P黄門ちゃま9ME2]　[8ch対応]
# 商品URL : https://home-slot.net/SHOP/p-heiwa252.html
# 画像URL : https://image1.shopserve.jp/home-slot.net/pic-labo/llimg/p_komon_ll259.jpg?t=20260129115406
# 価格    : 232500
# [DB] 保存完了
#
# ページ検出件数 : 40
# ページ保存件数 : 40
# [WAIT] 次のページまで10秒待機します
