# %%
import os
import re
import sqlite3
import sys
import time

from datetime import datetime
from urllib.parse import urljoin

import requests

from bs4 import BeautifulSoup


# ==================================================
# importパス設定
# ==================================================

# Jupyter・通常のPythonスクリプトの両方に対応
try:
    base_dir = os.path.dirname(
        os.path.abspath(__file__)
    )
except NameError:
    base_dir = os.getcwd()


project_root = os.path.abspath(
    os.path.join(
        base_dir,
        "..",
        "..",
    )
)


if project_root not in sys.path:
    sys.path.insert(
        0,
        project_root,
    )


from utils.config import (
    DB_PATH,
    PROXY_LIST,
    PROXY_MODE,
    PROXY_ROTATE_EVERY,
)


# ==================================================
# 初期設定
# ==================================================

start_time = time.time()

table_name = "result_table"


# ==================
# スクレイピングサイト設定
# ==================

SHOP_NAME = "家庭で楽しめる中古スロット【A-SLOT】"
SHOP_PRODUCT_ID = 3
CATEGORY = "slot"

BASE_URL = (
    "https://www.a-slot.com/"
    "SHOP/237227/t01/list{}.html"
)

MAX_PAGE = 100

# ページ間の待機秒数
REQUEST_INTERVAL = 10

# タイムアウト秒数
REQUEST_TIMEOUT = 120

# 1ページあたりの最大試行回数
MAX_RETRIES = 5

# リトライまでの待機秒数
RETRY_INTERVAL = 30


# ==================
# プロキシ
# ==================

def _resolve_proxy_for_batch(
    batch_index: int,
) -> str | None:

    mode = (
        PROXY_MODE or "none"
    ).strip().lower()

    if mode == "none":
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    if mode != "list":

        raw = (
            PROXY_MODE or ""
        ).strip()

        if raw.lower() == "none" or raw == "":
            print(
                f"[INFO] Proxy for batch {batch_index}: "
                "(none直結)"
            )
            return None

        proxy = (
            raw
            if "://" in raw
            else f"http://{raw}"
        )

        print(
            f"[INFO] Proxy for batch {batch_index}: "
            f"{proxy}"
        )

        return proxy

    if not PROXY_LIST:
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    step = max(
        1,
        int(PROXY_ROTATE_EVERY or 1),
    )

    idx = (
        batch_index // step
    ) % len(PROXY_LIST)

    pick = str(
        PROXY_LIST[idx]
    ).strip()

    if pick.lower() == "none" or pick == "":
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    proxy = (
        pick
        if "://" in pick
        else f"http://{pick}"
    )

    print(
        f"[INFO] Proxy for batch {batch_index}: "
        f"{proxy}"
    )

    return proxy


def open_session(
    batch_index: int = 0,
) -> requests.Session:

    proxy = _resolve_proxy_for_batch(
        batch_index
    )

    session = requests.Session()

    session.headers.update({
        "User-Agent": (
            "Mozilla/5.0 "
            "(Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 "
            "(KHTML, like Gecko) "
            "Chrome/138.0.0.0 "
            "Safari/537.36"
        )
    })

    if proxy:
        session.proxies = {
            "http": proxy,
            "https": proxy,
        }

    return session


# ==================
# ページ取得
# ==================

def get_page(
    session: requests.Session,
    url: str,
) -> requests.Response | None:

    for retry_count in range(
        1,
        MAX_RETRIES + 1,
    ):

        try:
            print(
                f"[REQUEST] 取得開始 "
                f"({retry_count}/{MAX_RETRIES})"
            )

            response = session.get(
                url,
                timeout=REQUEST_TIMEOUT,
            )

            if response.status_code == 200:
                return response

            print(
                f"[ERROR] HTTP "
                f"{response.status_code} "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ReadTimeout:
            print(
                f"[ERROR] 読み込みタイムアウト "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ConnectTimeout:
            print(
                f"[ERROR] 接続タイムアウト "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ConnectionError as e:
            print(
                f"[ERROR] 接続エラー "
                f"({retry_count}/{MAX_RETRIES}): {e}"
            )

        except requests.RequestException as e:
            print(
                f"[ERROR] リクエストエラー "
                f"({retry_count}/{MAX_RETRIES}): {e}"
            )

        # 最終試行でなければ待機して再試行
        if retry_count < MAX_RETRIES:
            print(
                f"[RETRY] {RETRY_INTERVAL}秒後に"
                "同じページを再試行します"
            )

            time.sleep(
                RETRY_INTERVAL
            )

    print(
        f"[ERROR] {MAX_RETRIES}回取得に失敗しました"
    )

    return None


# ==================
# DB
# ==================

def save_product(
    data: dict,
) -> None:

    conn = sqlite3.connect(
        DB_PATH
    )

    try:
        cur = conn.cursor()

        sql = f"""
        INSERT INTO {table_name}
        (
            shop_name,
            shop_product_id,
            category,
            machine_name,
            product_url,
            image_url,
            price,
            created_at
        )
        VALUES
        (?, ?, ?, ?, ?, ?, ?, ?)
        """

        cur.execute(
            sql,
            (
                SHOP_NAME,
                SHOP_PRODUCT_ID,
                CATEGORY,
                data["machine_name"],
                data["product_url"],
                data["image_url"],
                data["price"],
                datetime.now(),
            ),
        )

        conn.commit()

    except Exception:
        conn.rollback()
        raise

    finally:
        conn.close()


# ==================
# スクレイピング開始
# ==================

session = open_session()
total_count = 0


try:

    # ==================
    # ページループ
    # ==================

    for page in range(
        1,
        MAX_PAGE + 1,
    ):

        url = BASE_URL.format(
            page
        )

        print(
            f"\n{'=' * 80}"
        )
        print(
            f"Page {page}"
        )
        print(
            url
        )

        # --------------------------
        # ページ取得
        # --------------------------

        response = get_page(
            session,
            url,
        )

        if response is None:
            print(
                f"[ERROR] Page {page}の取得に"
                "失敗したため終了します"
            )
            break

        # 文字コードを自動判定
        response.encoding = (
            response.apparent_encoding
        )

        soup = BeautifulSoup(
            response.text,
            "html.parser",
        )

        item_list = soup.find(
            "div",
            id="itemList",
        )

        if item_list is None:
            print(
                "[ERROR] itemListが見つかりません"
            )
            break

        # 商品一覧
        # 1商品 = section.column4
        products = item_list.select(
            "section.column4"
        )

        found_count = len(
            products
        )

        saved_count = 0

        for product in products:

            # --------------------------
            # タイトル・商品URL
            # --------------------------

            a = product.select_one(
                "h2 > a"
            )

            if a is None:
                continue

            machine_name = a.get_text(
                " ",
                strip=True,
            )

            href = str(
                a.get(
                    "href",
                    "",
                )
                or ""
            ).strip()

            if not machine_name:
                print(
                    "[SKIP] 商品名が空です"
                )
                continue

            if not href:
                print(
                    f"[SKIP] 商品URLが空です: "
                    f"{machine_name}"
                )
                continue

            product_url = urljoin(
                url,
                href,
            )

            # --------------------------
            # 画像URL
            # --------------------------

            image_url = ""

            img = product.select_one(
                "span.item-list-span-img img"
            )

            if img:

                image_src = (
                    img.get("src")
                    or img.get("data-src")
                    or img.get("data-original")
                    or img.get("data-lazy-src")
                    or ""
                )

                if image_src:
                    image_url = urljoin(
                        url,
                        image_src,
                    )

            # --------------------------
            # 価格
            # --------------------------

            price = ""

            price_tag = product.select_one(
                "span.selling_price"
            )

            if price_tag:

                price_text = price_tag.get_text(
                    strip=True
                )

                price = re.sub(
                    r"[^\d]",
                    "",
                    price_text,
                )

            # --------------------------
            # 表示
            # --------------------------

            print(
                "-" * 80
            )
            print(
                "ショップ:",
                SHOP_NAME,
            )
            print(
                "カテゴリ:",
                CATEGORY,
            )
            print(
                "機種名  :",
                machine_name,
            )
            print(
                "商品URL :",
                product_url,
            )
            print(
                "画像URL :",
                image_url,
            )
            print(
                "価格    :",
                price,
            )

            # --------------------------
            # DB保存
            # --------------------------

            try:
                save_product({
                    "machine_name": machine_name,
                    "product_url": product_url,
                    "image_url": image_url,
                    "price": price,
                })

                print(
                    "[DB] 保存完了"
                )

            except sqlite3.Error as e:
                print(
                    f"[DB ERROR] 保存失敗: {e}"
                )
                continue

            saved_count += 1
            total_count += 1

        print(
            f"\nページ検出件数 : {found_count}"
        )
        print(
            f"ページ保存件数 : {saved_count}"
        )

        # 商品が無くなったら終了
        if found_count == 0:
            print(
                "商品がありません。終了します。"
            )
            break

        # 次のページへ進む前に待機
        if page < MAX_PAGE:
            print(
                f"[WAIT] 次のページまで"
                f"{REQUEST_INTERVAL}秒待機します"
            )

            time.sleep(
                REQUEST_INTERVAL
            )


finally:

    # ==================
    # 終了
    # ==================

    session.close()


# ==================
# 結果表示
# ==================

print(
    "\n" + "=" * 80
)
print(
    f"総取得件数 : {total_count}"
)
print(
    "=" * 80
)

end_time = time.time()

print(
    "[INFO] スクリプト完了"
    f"（実行時間: "
    f"{end_time - start_time:.2f} 秒）"
)
# Out:
# [INFO] Proxy for batch 0: (none直結)
#
# ================================================================================
# Page 1
# https://www.a-slot.com/SHOP/237227/t01/list1.html
# [REQUEST] 取得開始 (1/5)
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【塗装剥がれあり】北電子 パチスロこれはゾンビですか？　中古パチスロ実機 No.22266
# 商品URL : https://www.a-slot.com/SHOP/kitadensi87_22266.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/kore_zombi.jpg?t=20180407134554
# 価格    : 20683
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】山佐 スマスロ鉄拳6 中古パチスロ実機 [スマスロ]No.ps0730
# 商品URL : https://www.a-slot.com/SHOP/s-yamasa248_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/sma_tekken6.jpg?t=20260103122622
# 価格    : 39900
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】七匠 パチスロ　ベルセルク 中古パチスロ実機　[4ch対応]No.65312
# 商品URL : https://www.a-slot.com/SHOP/nanashow1_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/beruseruku.jpg?t=20150317164552
# 価格    : 79840
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【中リールにキズあり】銀座 パチスロ ディスクアップ [グリーンパネル] 中古パチスロ実機　[4ch対応] No.65224
# 商品URL : https://www.a-slot.com/SHOP/ginza203_65224.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/disc_up_3.jpg?t=20190412223125
# 価格    : 35400
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【コイン不要機プラチナ付き！】EXCITE パチスロ這いよれ!ニャル子さん 中古パチスロ実機　[4ch対応]No.65204
# 商品URL : https://www.a-slot.com/SHOP/s-excite204_z3.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/slo_nyaruko.jpg?t=20221202142731
# 価格    : 41720
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】KPE マジカルハロウィンJC バニーパネル 中古パチスロ実機　[8ch対応]No.64421
# 商品URL : https://www.a-slot.com/SHOP/kpe6_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/p4786_2.jpg?t=20080511041336
# 価格    : 62800
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 銀座 リングにかけろ パネル不問 中古パチスロ実機　[4ch対応]
# 商品URL : https://www.a-slot.com/SHOP/ginza2_zzz.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/p4578_1.jpg?t=20080523030523
# 価格    : 62800
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【上部にキズあり】スパイキー L ダーリン・イン・ザ・フランキス 中古パチスロ実機 [スマスロ][4ch対応][まるごと配送限定]No.65002
# 商品URL : https://www.a-slot.com/SHOP/s-spyki211_w.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/l_darlin_frankiss.jpg?t=20250730225703
# 価格    : 39065
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【コイン不要機ゴールド+クイック電源スイッチ付き！】KPE マジカルハロウィン5　[マジハロ5]　中古パチスロ実機 No.8258
# 商品URL : https://www.a-slot.com/SHOP/kpe53_8258.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/magical_halloween5.jpg?t=20160222005741
# 価格    : 49368
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【設定7基板プレミアム付き！】サミー パチスロ コードギアス 反逆のルルーシュ 中古パチスロ実機　[4ch対応] No.65093
# 商品URL : https://www.a-slot.com/SHOP/sammy80_65093.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/code-geass_main_image.jpg?t=20120331180416
# 価格    : 58291
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【メッキハゲ・中リールにハゲあり】大都技研　クレアの秘宝伝～眠りの塔とめざめの石～ 中古パチスロ実機　[8ch対応]No.5953
# 商品URL : https://www.a-slot.com/SHOP/daitogiken58_5953.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/kurea_memuri_mezame.jpg?t=20160820202038
# 価格    : 20230
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【お取り寄せ商品】スパイキー L 東京喰種 [有馬パネル] 中古パチスロ実機 [スマスロ][4ch対応][まるごと配送限定]
# 商品URL : https://www.a-slot.com/SHOP/s-spyki214.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/l_tokyo_ghoul_arima.jpg?t=20260709131415
# 価格    : 758700
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【液晶・下パネルにキズあり】ミズホ アナザーゴッドハーデス-解き放たれし槍撃ver.- 中古パチスロ実機　[8ch対応][まるごと配送限定]No.58283
# 商品URL : https://www.a-slot.com/SHOP/s-mizuho-macy217_58283.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/anothergod_sougeki.jpg?t=20230413160505
# 価格    : 19844
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】パイオニア スマート沖スロ スターハナハナ 中古パチスロ実機 [スマスロ]　[4ch対応]No.65038
# 商品URL : https://www.a-slot.com/SHOP/s-pioneer227_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/smaoki_star_hana.jpg?t=20250116124010
# 価格    : 83840
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】ミズホ ゆるせぽね 中古パチスロ実機 No.65095
# 商品URL : https://www.a-slot.com/SHOP/mizuho-macy68_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/yurusepone.jpg?t=20180527155933
# 価格    : 25432
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 北電子 ローティス 中古パチスロ実機 [スマスロ]　[4ch対応]
# 商品URL : https://www.a-slot.com/SHOP/s-kitadenshi223.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/lotes.jpg?t=20260702122325
# 価格    : 113500
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : オッケー. L ULTRAMAN 最終決戦 中古パチスロ実機 [スマスロ][8ch対応][まるごと配送限定]
# 商品URL : https://www.a-slot.com/SHOP/s-ok205.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/l_ultraman_final.jpg?t=20260702113930
# 価格    : 455200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【サブタンクなし】パイオニア ニューハナハナゴールド-30 中古パチスロ実機 No.61276
# 商品URL : https://www.a-slot.com/SHOP/pioneer208_61276.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/new_hanagold30.jpg?t=20210102181109
# 価格    : 25640
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【トップランプにキズあり】北電子 スーパーミラクルジャグラー　中古パチスロ実機　[4ch対応]No.57410
# 商品URL : https://www.a-slot.com/SHOP/kitadensi84_57410.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/super_miraclejuggler.jpg?t=20170617152314
# 価格    : 41004
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【コイン不要機ブロンズ付き！】平和 Sキャッツ・アイ 中古パチスロ実機　[8ch対応]No.38835
# 商品URL : https://www.a-slot.com/SHOP/s-heiwa220_z1.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/s_cats_eye.jpg?t=20220603152801
# 価格    : 30385
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】コナミアミューズメント パチスロ 転生したら剣でした 中古パチスロ実機 [スマスロ]　[4ch対応]No.64975
# 商品URL : https://www.a-slot.com/SHOP/s-konami224_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/slo_tensei_ken.jpg?t=20250731150704
# 価格    : 39078
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【コイン不要機ブロンズ付き！】【4号機】ニイガタ電子(山佐) 鉄拳X 中古パチスロ実機　[4ch対応]No.64815
# 商品URL : https://www.a-slot.com/SHOP/yamasa29_z1.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/p4395_1.jpg?t=20090409041629
# 価格    : 40515
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【下パネルフィルムに透けあり】【コイン不要機ブロンズ付き！】大都技研 政宗 中古パチスロ実機　[4ch対応]No.64801
# 商品URL : https://www.a-slot.com/SHOP/daitogiken36_64801.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/masamune_image.jpg?t=20110815173726
# 価格    : 39382
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】ビスティ Lパチスロ 機動戦士ガンダムユニコーン 覚醒DRIVE 中古パチスロ実機 [スマスロ]　[4ch対応]No.ps0730
# 商品URL : https://www.a-slot.com/SHOP/s-bisty227_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/gundam_uc_drive.jpg?t=20260417152853
# 価格    : 48000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【中リールに凹みあり】【コイン不要機ブロンズ付き！】アリストクラート 巨人の星5～汗と涙と根性編～ 中古パチスロ実機　[4ch対応]No.64814
# 商品URL : https://www.a-slot.com/SHOP/aristocrat17_64814.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/018987_main_image_s.jpg?t=20111018163250
# 価格    : 36260
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【コイン不要機ブロンズ付き！】藤商事 パチスロ FAIRY TAIL フェアリーテイル [メインパネル] 中古パチスロ実機　[4ch対応]No.64691
# 商品URL : https://www.a-slot.com/SHOP/fuji22_z1.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/slo_fairy_tail_main.jpg?t=20180506150318
# 価格    : 36974
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【リールに割れ・凹みあり】北電子 ノーゲーム・ノーライフ THE SLOT 中古パチスロ実機 [8ch対応]No.57637
# 商品URL : https://www.a-slot.com/SHOP/kitadensi205_57637.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/no_game_no_life_slot.jpg?t=20210614124849
# 価格    : 29309
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【コイン不要機ブロンズ付き！】サミー パチスロ化物語 ヒロインパネル 中古パチスロ実機　[4ch対応]No.64679
# 商品URL : https://www.a-slot.com/SHOP/sammy102_z1.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/bakemnomonogatari_hiroin.jpg?t=20140131153412
# 価格    : 63426
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : ユニバーサルブロス スマスロ BIRDIE WING ‐Golf Girls' Story‐ 中古パチスロ実機 [スマスロ][8ch対応][まるごと配送限定]
# 商品URL : https://www.a-slot.com/SHOP/s-univerasal206.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/birdiewing_golfgirls.jpg?t=20260603142751
# 価格    : 56500
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : オリンピア L戦国乙女5 業火を穿つ宿焔の双刃 中古パチスロ実機 [スマスロ]
# 商品URL : https://www.a-slot.com/SHOP/s-olympia240.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/l_senoto5gouka.jpg?t=20260603141314
# 価格    : 1600700
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】サミー パチスロ頭文字D 啓介パネル 中古パチスロ実機　[8ch対応][まるごと配送限定]No.64464
# 商品URL : https://www.a-slot.com/SHOP/sammy211_keisuke_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/slo_initial-d_keisuke.jpg?t=20260519105705
# 価格    : 27898
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】銀座 パチスロ シティーハンター 中古パチスロ実機　[4ch対応]No.64567
# 商品URL : https://www.a-slot.com/SHOP/ginza28_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/Cityhunter.jpg?t=20121207112038
# 価格    : 44506
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【右リールに凹みあり】【コイン不要機ブロンズ付き！】サミー パチスロ チェインクロニクル　中古パチスロ実機　[4ch対応]No.64460
# 商品URL : https://www.a-slot.com/SHOP/sammy202_64460.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/chain_chronicle.jpg?t=20181103171212
# 価格    : 16626
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】アデリオン スマスロ 鬼武者3 中古パチスロ実機 [スマスロ][8ch対応][まるごと配送限定]No.58738
# 商品URL : https://www.a-slot.com/SHOP/s-adelion205_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/sum_onimusya3.jpg?t=20241006080409
# 価格    : 33066
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : オーイズミ LBスロットGALFY 中古パチスロ実機 [スマスロ]　[8ch対応]
# 商品URL : https://www.a-slot.com/SHOP/s-oizumi220.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/lb_slot_galfy.jpg?t=20260521200507
# 価格    : 198700
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】藤商事 スマスロ とある科学の超電磁砲2 中古パチスロ実機 [スマスロ]　[4ch対応]No.ps0730
# 商品URL : https://www.a-slot.com/SHOP/s-fuji209_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/sma_accelerator2.jpg?t=20251031141808
# 価格    : 118000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : サミー パチスロ頭文字D 啓介パネル 中古パチスロ実機　[8ch対応][まるごと配送限定]
# 商品URL : https://www.a-slot.com/SHOP/sammy211_keisuke.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/slo_initial-d_keisuke.jpg?t=20260519105705
# 価格    : 48100
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【コイン不要機ブロンズ付き！】オリンピア キュインぱちすろ南国育ち 1st vacation 中古パチスロ実機　[4ch対応] No.64467
# 商品URL : https://www.a-slot.com/SHOP/heiwa81_z1.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/nangoku_1st_vacation.jpg?t=20120831122557
# 価格    : 55370
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】【コイン不要機ブロンズ付き！】オーイズミ パチスロOVERLORD絶対支配者光臨II 中古パチスロ実機 [8ch対応][まるごと配送限定]No.58716
# 商品URL : https://www.a-slot.com/SHOP/s-oizumi213_z1.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/overlord_korin2.jpg?t=20230316173901
# 価格    : 26895
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 家庭で楽しめる中古スロット【A-SLOT】
# カテゴリ: slot
# 機種名  : 【ビッグサマーセール】サミー パチスロ獣王 王者の帰還 中古パチスロ実機　[4ch対応]No.64328
# 商品URL : https://www.a-slot.com/SHOP/sammy100_z.html
# 画像URL : https://image1.shopserve.jp/a-slot.com/pic-labo/llimg/jyuou_ounokikan.jpg?t=20131130163941
# 価格    : 40404
# [DB] 保存完了
#
# ページ検出件数 : 40
# ページ保存件数 : 40
# [WAIT] 次のページまで10秒待機します
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 588
#     582         if page < MAX_PAGE:
#     583             print(
#     584                 f"[WAIT] 次のページまで"
#     585                 f"{REQUEST_INTERVAL}秒待機します"
#     586             )
# --> 588             time.sleep(
#     589                 REQUEST_INTERVAL
#     590             )
#     593 finally:
#     594
#     595     # ==================
#     596     # 終了
#     597     # ==================
#     599     session.close()
#
# KeyboardInterrupt:
