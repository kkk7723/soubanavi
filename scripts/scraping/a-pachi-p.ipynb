# %%
import os
import re
import sqlite3
import sys
import time

from datetime import datetime
from urllib.parse import urljoin

import requests

from bs4 import BeautifulSoup


# ==================================================
# importパス設定
# ==================================================

# Jupyter・通常のPythonスクリプトの両方に対応
try:
    base_dir = os.path.dirname(
        os.path.abspath(__file__)
    )
except NameError:
    base_dir = os.getcwd()


project_root = os.path.abspath(
    os.path.join(
        base_dir,
        "..",
        "..",
    )
)


if project_root not in sys.path:
    sys.path.insert(
        0,
        project_root,
    )


from utils.config import (
    DB_PATH,
    PROXY_LIST,
    PROXY_MODE,
    PROXY_ROTATE_EVERY,
)


# ==================================================
# 初期設定
# ==================================================

start_time = time.time()
now = datetime.now()

table_name = "result_table"


# ==================
# スクレイピングサイト設定
# ==================

SHOP_NAME = "【A-PACHINKO】家庭で楽しめる中古パチンコ"
SHOP_PRODUCT_ID = 1
CATEGORY = "pachi"

BASE_URL = (
    "https://www.a-pachinko.com/"
    "SHOP/496352/t01/list{}.html"
)

MAX_PAGE = 100

# ページ間の待機秒数
REQUEST_INTERVAL = 10

# タイムアウト秒数
REQUEST_TIMEOUT = 120

# 1ページあたりの最大再試行回数
MAX_RETRIES = 5

# 再試行までの待機秒数
RETRY_INTERVAL = 30


# ==================
# プロキシ
# ==================

def _resolve_proxy_for_batch(
    batch_index: int,
) -> str | None:

    mode = (
        PROXY_MODE or "none"
    ).strip().lower()

    if mode == "none":
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    if mode != "list":

        raw = (
            PROXY_MODE or ""
        ).strip()

        if raw.lower() == "none" or raw == "":
            print(
                f"[INFO] Proxy for batch {batch_index}: "
                "(none直結)"
            )
            return None

        proxy = (
            raw
            if "://" in raw
            else f"http://{raw}"
        )

        print(
            f"[INFO] Proxy for batch {batch_index}: "
            f"{proxy}"
        )

        return proxy

    if not PROXY_LIST:
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    step = max(
        1,
        int(PROXY_ROTATE_EVERY or 1),
    )

    idx = (
        batch_index // step
    ) % len(PROXY_LIST)

    pick = str(
        PROXY_LIST[idx]
    ).strip()

    if pick.lower() == "none" or pick == "":
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    proxy = (
        pick
        if "://" in pick
        else f"http://{pick}"
    )

    print(
        f"[INFO] Proxy for batch {batch_index}: "
        f"{proxy}"
    )

    return proxy


def open_session(
    batch_index: int = 0,
) -> requests.Session:

    proxy = _resolve_proxy_for_batch(
        batch_index
    )

    session = requests.Session()

    session.headers.update({
        "User-Agent": (
            "Mozilla/5.0 "
            "(Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 "
            "(KHTML, like Gecko) "
            "Chrome/138.0.0.0 "
            "Safari/537.36"
        )
    })

    if proxy:
        session.proxies = {
            "http": proxy,
            "https": proxy,
        }

    return session


# ==================
# ページ取得
# ==================

def get_page(
    session: requests.Session,
    url: str,
) -> requests.Response | None:

    for retry_count in range(
        1,
        MAX_RETRIES + 1,
    ):

        try:
            print(
                f"[REQUEST] 取得開始 "
                f"({retry_count}/{MAX_RETRIES})"
            )

            response = session.get(
                url,
                timeout=REQUEST_TIMEOUT,
            )

            if response.status_code == 200:
                return response

            print(
                f"[ERROR] HTTP "
                f"{response.status_code}"
            )

        except requests.exceptions.ReadTimeout:
            print(
                f"[ERROR] 読み込みタイムアウト "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ConnectTimeout:
            print(
                f"[ERROR] 接続タイムアウト "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ConnectionError as e:
            print(
                f"[ERROR] 接続エラー "
                f"({retry_count}/{MAX_RETRIES}): {e}"
            )

        except requests.RequestException as e:
            print(
                f"[ERROR] リクエストエラー "
                f"({retry_count}/{MAX_RETRIES}): {e}"
            )

        # 最終試行でなければ待機して再試行
        if retry_count < MAX_RETRIES:
            print(
                f"[RETRY] {RETRY_INTERVAL}秒後に"
                "同じページを再試行します"
            )

            time.sleep(
                RETRY_INTERVAL
            )

    print(
        f"[ERROR] {MAX_RETRIES}回取得に失敗しました"
    )

    return None


# ==================
# DB
# ==================

def save_product(
    data: dict,
) -> None:

    conn = sqlite3.connect(
        DB_PATH
    )

    try:
        cur = conn.cursor()

        sql = f"""
        INSERT INTO {table_name}
        (
            shop_name,
            shop_product_id,
            category,
            machine_name,
            product_url,
            image_url,
            price,
            created_at
        )
        VALUES
        (?, ?, ?, ?, ?, ?, ?, ?)
        """

        cur.execute(
            sql,
            (
                SHOP_NAME,
                SHOP_PRODUCT_ID,
                CATEGORY,
                data["machine_name"],
                data["product_url"],
                data["image_url"],
                data["price"],
                datetime.now(),
            ),
        )

        conn.commit()

    except Exception:
        conn.rollback()
        raise

    finally:
        conn.close()


# ==================
# スクレイピング開始
# ==================

session = open_session()
total_count = 0


try:

    # ==================
    # ページループ
    # ==================

    for page in range(
        1,
        MAX_PAGE + 1,
    ):

        url = BASE_URL.format(
            page
        )

        print(
            f"\n{'=' * 80}"
        )
        print(
            f"Page {page}"
        )
        print(
            url
        )

        # --------------------------
        # ページ取得
        # --------------------------

        response = get_page(
            session,
            url,
        )

        if response is None:
            print(
                f"[ERROR] Page {page}の取得に"
                "失敗したため終了します"
            )
            break

        # 文字コードを自動判定
        response.encoding = (
            response.apparent_encoding
        )

        soup = BeautifulSoup(
            response.text,
            "html.parser",
        )

        item_list = soup.find(
            "div",
            id="itemList",
        )

        if item_list is None:
            print(
                "[ERROR] itemListが見つかりません"
            )
            break

        # 商品一覧
        # 1商品 = section.column4
        products = item_list.select(
            "section.column4"
        )

        page_count = 0

        for product in products:

            # --------------------------
            # タイトル・商品URL
            # --------------------------

            a = product.select_one(
                "h2 > a"
            )

            if a is None:
                continue

            machine_name = a.get_text(
                strip=True
            )

            href = a.get(
                "href",
                "",
            )

            product_url = urljoin(
                url,
                href,
            )

            # --------------------------
            # 画像URL
            # --------------------------

            image_url = ""

            img = product.select_one(
                "span.item-list-span-img img"
            )

            if img:

                image_src = img.get(
                    "src",
                    "",
                )

                if image_src:
                    image_url = urljoin(
                        url,
                        image_src,
                    )

            # --------------------------
            # 価格
            # --------------------------

            price = ""

            price_tag = product.select_one(
                "span.selling_price"
            )

            if price_tag:

                price_text = price_tag.get_text(
                    strip=True
                )

                price = re.sub(
                    r"[^\d]",
                    "",
                    price_text,
                )

            # --------------------------
            # 表示
            # --------------------------

            print(
                "-" * 80
            )
            print(
                "ショップ:",
                SHOP_NAME,
            )
            print(
                "カテゴリ:",
                CATEGORY,
            )
            print(
                "機種名  :",
                machine_name,
            )
            print(
                "商品URL :",
                product_url,
            )
            print(
                "画像URL :",
                image_url,
            )
            print(
                "価格    :",
                price,
            )

            # --------------------------
            # DB保存
            # --------------------------

            try:
                save_product({
                    "machine_name": machine_name,
                    "product_url": product_url,
                    "image_url": image_url,
                    "price": price,
                })

                print(
                    "[DB] 保存完了"
                )

            except sqlite3.Error as e:
                print(
                    f"[DB ERROR] 保存失敗: {e}"
                )
                continue

            page_count += 1
            total_count += 1

        print(
            f"\nページ取得件数 : {page_count}"
        )

        # 商品が無くなったら終了
        if page_count == 0:
            print(
                "商品がありません。終了します。"
            )
            break

        # 次のページへ進む前に待機
        if page < MAX_PAGE:
            print(
                f"[WAIT] 次のページまで"
                f"{REQUEST_INTERVAL}秒待機します"
            )

            time.sleep(
                REQUEST_INTERVAL
            )


finally:

    # ==================
    # 終了
    # ==================

    session.close()


# ==================
# 結果表示
# ==================

print(
    "\n" + "=" * 80
)
print(
    f"総取得件数 : {total_count}"
)
print(
    "=" * 80
)

end_time = time.time()

print(
    "[INFO] スクリプト完了"
    f"（実行時間: "
    f"{end_time - start_time:.2f} 秒）"
)
# Out:
# [INFO] Proxy for batch 0: (none直結)
#
# ================================================================================
# Page 1
# https://www.a-pachinko.com/SHOP/496352/t01/list1.html
# [REQUEST] 取得開始 (1/5)
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】【A-コントローラーPlus付き！】メーシー Pハイスクール・フリート 枠色不問 中古パチンコ実機　[枠名：ＢＡＺＯＯＫＡ　響]　[4ch対応]No.38889
# 商品URL : https://www.a-pachinko.com/SHOP/macy205_38889.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/p_high_school_fleet.jpg?t=20190815151425
# 価格    : 55080
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】豊丸 P少女☆歌劇 レヴュースタァライト ラッキートリガー4500 中古パチンコ実機 [枠名：Ｔ１６Ｓ]No.64841
# 商品URL : https://www.a-pachinko.com/SHOP/p-toyomaru251_z.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/revuestarlight_lucky4500.jpg?t=20250403163527
# 価格    : 97920
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】SANKYO Pフィーバー革命機ヴァルヴレイヴ2 Lightver. 枠色不問 中古パチンコ実機　[枠名：NEO STELLA]　[4ch対応]No.64840
# 商品URL : https://www.a-pachinko.com/SHOP/p-sankyo252_z.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/fever_vvv2lt.jpg?t=20220219132554
# 価格    : 39582
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】SANYO P大海物語5 ブラック 中古パチンコ実機　[枠名：クリスタルシェル]　[2ch対応]No.64848
# 商品URL : https://www.a-pachinko.com/SHOP/p-sanyo249_z.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/seastory5_bk.jpg?t=20231130172546
# 価格    : 211260
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】【A-コントローラーPlus付き！】SANKYO Pフィーバー戦姫絶唱シンフォギア4 199 ver. 枠色不問 中古パチンコ実機　[枠名：フリーダム]　[4ch対応]No.61101
# 商品URL : https://www.a-pachinko.com/SHOP/p-sankyo289_61101.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/p_fv_symphogear4_199.jpg?t=20250129152340
# 価格    : 77462
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】SANKYO Pフィーバー戦姫絶唱シンフォギア4 199 ver. 中古パチンコ実機　[枠名：フリーダム]　[4ch対応]No.63372
# 商品URL : https://www.a-pachinko.com/SHOP/p-sankyo289_z.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/p_fv_symphogear4_199.jpg?t=20250129152340
# 価格    : 58366
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  

# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : メーシー P沖ドキ！ドキドキ弾丸ツアー 中古パチンコ実機　[枠名：SHINOBI7　P沖ドキ!LG]　[8ch対応]
# 商品URL : https://www.a-pachinko.com/SHOP/p-macy237.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/okidoki_dangan.jpg?t=20260317230314
# 価格    : 135300
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : メーシー Pえとたま2 神祭 干支甘 中古パチンコ実機　[枠名：SHINOBI7　えとたま2SE]　[8ch対応]
# 商品URL : https://www.a-pachinko.com/SHOP/p-macy236.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/p_etotama2eto.jpg?t=20260317134214
# 価格    : 149000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 竹屋 PキングモンスターRUSH 67Ver. 中古パチンコ実機　[枠名：SWGT]　[4ch対応]
# 商品URL : https://www.a-pachinko.com/SHOP/p-takeya207.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/kingmonster67.jpg?t=20260312220951
# 価格    : 496500
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 七匠 スマパチ SSSS.GRIDMAN メガSTART 159ver. 中古パチンコ実機 [スマパチ]　[枠名：七匠Cygnus　グリッドマンBDN]　[4ch対応]
# 商品URL : https://www.a-pachinko.com/SHOP/p-nanashow205.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/s_ssss_gridman159.jpg?t=20260312154103
# 価格    : 99000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 京楽 e 乃木坂46 II SWEET Version 中古パチンコ実機 [スマパチ]　[枠名：新枠　e 乃木坂46 II SWEET version]　[4ch対応]
# 商品URL : https://www.a-pachinko.com/SHOP/p-kyoraku249.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/e_nogizaka46_2sweet.jpg?t=20260312145517
# 価格    : 214200
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】銀座 Pモンスターハンターライズ 中古パチンコ実機　[枠名：銀座真焔「ウェーブギア」]　[4ch対応]No.63841
# 商品URL : https://www.a-pachinko.com/SHOP/p-ginza223_z.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/p_monhun_rise.jpg?t=20241030135836
# 価格    : 39360
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 銀座 e 甲鉄城のカバネリ2 咲かせや燦然 中古パチンコ実機 [スマパチ]　[枠名：誓]　[4ch対応]
# 商品URL : https://www.a-pachinko.com/SHOP/p-ginza233.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/e_kabaneri2sakase.jpg?t=20260228230339
# 価格    : 100400
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】SANKYO Pフィーバー炎炎ノ消防隊Light ver. 枠色不問 中古パチンコ実機　[枠名：NEO STELLA]　[4ch対応]No.63418
# 商品URL : https://www.a-pachinko.com/SHOP/p-sankyo278_z.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/fv_enn_shouboutai_lt.jpg?t=20240502151458
# 価格    : 36360
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】サミー P北斗の拳 暴凶星 中古パチンコ実機　[枠名：真焔]　[4ch対応]No.63414
# 商品URL : https://www.a-pachinko.com/SHOP/p-sammy238_z.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/hokuto_boukyousei.jpg?t=20230503155358
# 価格    : 45450
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: 【A-PACHINKO】家庭で楽しめる中古パチンコ
# カテゴリ: pachi
# 機種名  : 【ビッグサマーセール】ジェイビー Pフィーバークィーン2 中古パチンコ実機　[枠名：JB NEO STELLA]　[4ch対応]No.63389
# 商品URL : https://www.a-pachinko.com/SHOP/jb207_z.html
# 画像URL : https://image1.shopserve.jp/a-pachinko.com/pic-labo/llimg/feverqueen2.jpg?t=20201003112537
# 価格    : 35184
# [DB] 保存完了
#
# ページ取得件数 : 40
# [WAIT] 次のページまで10秒待機します
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 561
#     555         if page < MAX_PAGE:
#     556             print(
#     557                 f"[WAIT] 次のページまで"
#     558                 f"{REQUEST_INTERVAL}秒待機します"
#     559             )
# --> 561             time.sleep(
#     562                 REQUEST_INTERVAL
#     563             )
#     566 finally:
#     567
#     568     # ==================
#     569     # 終了
#     570     # ==================
#     572     session.close()
#
# KeyboardInterrupt:
