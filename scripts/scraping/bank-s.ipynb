# %%
import os
import re
import sqlite3
import sys
import time

from datetime import datetime
from urllib.parse import urljoin

import requests

from bs4 import BeautifulSoup


# ==================================================
# importパス設定
# ==================================================

# Jupyter・通常のPythonスクリプトの両方に対応
try:
    base_dir = os.path.dirname(
        os.path.abspath(__file__)
    )
except NameError:
    base_dir = os.getcwd()


project_root = os.path.abspath(
    os.path.join(
        base_dir,
        "..",
        "..",
    )
)


if project_root not in sys.path:
    sys.path.insert(
        0,
        project_root,
    )


from utils.config import (
    DB_PATH,
    PROXY_LIST,
    PROXY_MODE,
    PROXY_ROTATE_EVERY,
)


# ==================================================
# 初期設定
# ==================================================

start_time = time.time()

table_name = "result_table"


# ==================
# スクレイピングサイト設定
# ==================

SHOP_NAME = "パチスロ中古実機販売なら【パチスロバンク】"
SHOP_PRODUCT_ID = 6
CATEGORY = "slot"

BASE_URL = (
    "https://pachislobank.com/SHOP/list.php"
    "?a8=JgHMsgTYwGo8mZ7NmkSN8G0f2Ker3fpLSkS8TG7pV8AYwGHEyGPoXNHGIN96v6nSX8zNpdHoXgHMUs00000013468001"
    "&Search="
    "&Type=01"
    "&PAGE={}.html"
)

MAX_PAGE = 100

# ページ間の待機秒数
REQUEST_INTERVAL = 10

# 1回のリクエストのタイムアウト秒数
REQUEST_TIMEOUT = 120

# 1ページあたりの最大試行回数
MAX_RETRIES = 5

# リトライまでの待機秒数
RETRY_INTERVAL = 30


# ==================
# プロキシ
# ==================

def _resolve_proxy_for_batch(
    batch_index: int,
) -> str | None:

    mode = (
        PROXY_MODE or "none"
    ).strip().lower()

    if mode == "none":
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    if mode != "list":

        raw = (
            PROXY_MODE or ""
        ).strip()

        if raw.lower() == "none" or raw == "":
            print(
                f"[INFO] Proxy for batch {batch_index}: "
                "(none直結)"
            )
            return None

        proxy = (
            raw
            if "://" in raw
            else f"http://{raw}"
        )

        print(
            f"[INFO] Proxy for batch {batch_index}: "
            f"{proxy}"
        )

        return proxy

    if not PROXY_LIST:
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    step = max(
        1,
        int(PROXY_ROTATE_EVERY or 1),
    )

    idx = (
        batch_index // step
    ) % len(PROXY_LIST)

    pick = str(
        PROXY_LIST[idx]
    ).strip()

    if pick.lower() == "none" or pick == "":
        print(
            f"[INFO] Proxy for batch {batch_index}: "
            "(none直結)"
        )
        return None

    proxy = (
        pick
        if "://" in pick
        else f"http://{pick}"
    )

    print(
        f"[INFO] Proxy for batch {batch_index}: "
        f"{proxy}"
    )

    return proxy


def open_session(
    batch_index: int = 0,
) -> requests.Session:

    proxy = _resolve_proxy_for_batch(
        batch_index
    )

    session = requests.Session()

    session.headers.update({
        "User-Agent": (
            "Mozilla/5.0 "
            "(Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 "
            "(KHTML, like Gecko) "
            "Chrome/138.0.0.0 "
            "Safari/537.36"
        )
    })

    if proxy:
        session.proxies = {
            "http": proxy,
            "https": proxy,
        }

    return session


# ==================
# ページ取得
# ==================

def get_page(
    session: requests.Session,
    url: str,
) -> requests.Response | None:

    for retry_count in range(
        1,
        MAX_RETRIES + 1,
    ):

        try:
            print(
                f"[REQUEST] 取得開始 "
                f"({retry_count}/{MAX_RETRIES})"
            )

            response = session.get(
                url,
                timeout=REQUEST_TIMEOUT,
            )

            if response.status_code == 200:
                return response

            print(
                f"[ERROR] HTTP "
                f"{response.status_code} "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ReadTimeout:
            print(
                f"[ERROR] 読み込みタイムアウト "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ConnectTimeout:
            print(
                f"[ERROR] 接続タイムアウト "
                f"({retry_count}/{MAX_RETRIES})"
            )

        except requests.exceptions.ConnectionError as e:
            print(
                f"[ERROR] 接続エラー "
                f"({retry_count}/{MAX_RETRIES}): {e}"
            )

        except requests.RequestException as e:
            print(
                f"[ERROR] リクエストエラー "
                f"({retry_count}/{MAX_RETRIES}): {e}"
            )

        # 最終試行でなければ待機して再試行
        if retry_count < MAX_RETRIES:
            print(
                f"[RETRY] {RETRY_INTERVAL}秒後に"
                "同じページを再試行します"
            )

            time.sleep(
                RETRY_INTERVAL
            )

    print(
        f"[ERROR] {MAX_RETRIES}回取得に失敗しました"
    )

    return None


# ==================
# DB
# ==================

def save_product(
    data: dict,
) -> None:

    conn = sqlite3.connect(
        DB_PATH
    )

    try:
        cur = conn.cursor()

        sql = f"""
        INSERT INTO {table_name}
        (
            shop_name,
            shop_product_id,
            category,
            machine_name,
            product_url,
            image_url,
            price,
            created_at
        )
        VALUES
        (?, ?, ?, ?, ?, ?, ?, ?)
        """

        cur.execute(
            sql,
            (
                SHOP_NAME,
                SHOP_PRODUCT_ID,
                CATEGORY,
                data["machine_name"],
                data["product_url"],
                data["image_url"],
                data["price"],
                datetime.now(),
            ),
        )

        conn.commit()

    except Exception:
        conn.rollback()
        raise

    finally:
        conn.close()


# ==================
# スクレイピング開始
# ==================

session = open_session()
total_count = 0


try:

    # ==================
    # ページループ
    # ==================

    for page in range(
        1,
        MAX_PAGE + 1,
    ):

        url = BASE_URL.format(
            page
        )

        print(
            f"\n{'=' * 80}"
        )
        print(
            f"Page {page}"
        )
        print(
            url
        )

        # --------------------------
        # ページ取得
        # --------------------------

        response = get_page(
            session,
            url,
        )

        if response is None:
            print(
                f"[ERROR] Page {page}の取得に"
                "失敗したため終了します"
            )
            break

        # 文字コードを自動判定
        response.encoding = (
            response.apparent_encoding
        )

        soup = BeautifulSoup(
            response.text,
            "html.parser",
        )

        item_list = soup.find(
            "div",
            id="itemList",
        )

        if item_list is None:
            print(
                "[ERROR] itemListが見つかりません"
            )
            break

        # 商品一覧
        # 1商品 = section.column4
        products = item_list.select(
            "section.column4"
        )

        found_count = len(
            products
        )

        saved_count = 0

        for product in products:

            # --------------------------
            # タイトル・商品URL
            # --------------------------

            a = product.select_one(
                "h2 > a"
            )

            if a is None:
                continue

            machine_name = a.get_text(
                " ",
                strip=True,
            )

            href = str(
                a.get(
                    "href",
                    "",
                )
                or ""
            ).strip()

            if not machine_name:
                print(
                    "[SKIP] 商品名が空です"
                )
                continue

            if not href:
                print(
                    f"[SKIP] 商品URLが空です: "
                    f"{machine_name}"
                )
                continue

            product_url = urljoin(
                url,
                href,
            )

            # --------------------------
            # 画像URL
            # --------------------------

            image_url = ""

            img = product.select_one(
                "span.item-list-span-img img"
            )

            if img:

                image_src = (
                    img.get("src")
                    or img.get("data-src")
                    or img.get("data-original")
                    or img.get("data-lazy-src")
                    or ""
                )

                if image_src:
                    image_url = urljoin(
                        url,
                        image_src,
                    )

            # --------------------------
            # 価格
            # --------------------------

            price = ""

            price_tag = product.select_one(
                "span.selling_price"
            )

            if price_tag:

                price_text = price_tag.get_text(
                    strip=True
                )

                price = re.sub(
                    r"[^\d]",
                    "",
                    price_text,
                )

            # --------------------------
            # 表示
            # --------------------------

            print(
                "-" * 80
            )
            print(
                "ショップ:",
                SHOP_NAME,
            )
            print(
                "カテゴリ:",
                CATEGORY,
            )
            print(
                "機種名  :",
                machine_name,
            )
            print(
                "商品URL :",
                product_url,
            )
            print(
                "画像URL :",
                image_url,
            )
            print(
                "価格    :",
                price,
            )

            # --------------------------
            # DB保存
            # --------------------------

            try:
                save_product({
                    "machine_name": machine_name,
                    "product_url": product_url,
                    "image_url": image_url,
                    "price": price,
                })

                print(
                    "[DB] 保存完了"
                )

            except sqlite3.Error as e:
                print(
                    f"[DB ERROR] 保存失敗: {e}"
                )
                continue

            saved_count += 1
            total_count += 1

        print(
            f"\nページ検出件数 : {found_count}"
        )
        print(
            f"ページ保存件数 : {saved_count}"
        )

        # 商品自体が無くなったら終了
        if found_count == 0:
            print(
                "商品がありません。終了します。"
            )
            break

        # 次のページへ進む前に待機
        if page < MAX_PAGE:
            print(
                f"[WAIT] 次のページまで"
                f"{REQUEST_INTERVAL}秒待機します"
            )

            time.sleep(
                REQUEST_INTERVAL
            )


finally:

    # ==================
    # 終了
    # ==================

    session.close()


# ==================
# 結果表示
# ==================

print(
    "\n" + "=" * 80
)
print(
    f"総取得件数 : {total_count}"
)
print(
    "=" * 80
)

end_time = time.time()

print(
    "[INFO] スクリプト完了"
    f"（実行時間: "
    f"{end_time - start_time:.2f} 秒）"
)
# Out:
# [INFO] Proxy for batch 0: (none直結)
#
# ================================================================================
# Page 1
# https://pachislobank.com/SHOP/list.php?a8=JgHMsgTYwGo8mZ7NmkSN8G0f2Ker3fpLSkS8TG7pV8AYwGHEyGPoXNHGIN96v6nSX8zNpdHoXgHMUs00000013468001&Search=&Type=01&PAGE=1.html
# [REQUEST] 取得開始 (1/5)
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : 【訳あり：液晶面傷】パチスロ実機　エンターライズ（アデリオン）ＬモンスターハンターライズＸＡ【ハンターパネル】【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-enterrise0033-1.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/rize_hunterp.jpg?t=20260522114344
# 価格    : 32000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　北電子（ゼクロスクリエイティブ）　 ＬバーニングエクスプレスＺＮ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-kitac0056.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/burning_express.jpg?t=20260319162704
# 価格    : 39000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　大都技研　 爺サマー
# 商品URL : https://pachislobank.com/SHOP/s-daito0091.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/jiissammer.jpg?t=20260319161202
# 価格    : 55000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　山佐　Ｌパチスロ鉄拳６ＹＤ０１Ｈ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-yamasa0136.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_tekken6.jpg?t=20260218182653
# 価格    : 62000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　大都技研（パオン・ディーピー）　Ｌ／スマスロ秘宝伝／ＰＡ７【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-daito0090.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_hihouden.jpg?t=20260129164024
# 価格    : 39000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　山佐（セブンリーグ）　 ＬネオプラネットＳＬＥＤ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-yamasa0135.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_neoplanet.jpg?t=20260116154740
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　藤商事　Ｌとある科学の超電磁砲２ＦＶ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-fujisyouji0034.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/l_railgun2.jpg?t=20260115182456
# 価格    : 120000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　Ｄａｉｉｃｈｉ（アイドル）　Ｌ絶対衝激フォースＦＨ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-daiichi0023.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/zettaishogeki4.jpg?t=20260115180758
# 価格    : 47000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　SANKYO（ジェイビー）　Ｌ革命機ヴァルヴレイヴ２ｊＦ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-sankyo0064.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/vvv2.jpg?t=20251119164110
# 価格    : 59000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　エンターライズ（レオスター）　Ｌ新鬼武者３ＳＡ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-enterrise0036.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_shinoni3.jpg?t=20251112154045
# 価格    : 52000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　ユニバーサルブロス　  Ｌ／バベル／ＢＡ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-univaersal-bros0014.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_babel.jpg?t=20251112144706
# 価格    : 39000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　三洋　Ｌ咲－Ｓａｋｉ－頂上決戦ＹＲ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-sanyo0040.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_saki.jpg?t=20251022123524
# 価格    : 40000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　スパイキー　ＬダーリンインザフランキスＳＡ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-spiky0030.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/darlyn.jpg?t=20250925164051
# 価格    : 45000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　KPE（グレードワン）　Ｌ転生したら剣でしたＧＴ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-kpe0076.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/tenseishitara_ken.jpg?t=20250925163037
# 価格    : 48000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　SANKYO　LBパチスロ エヴァンゲリオン ～約束の扉～（ＬＢエヴァンゲリオンｓＲ）【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-sankyo0063.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/LB_eva_yakusoku.jpg?t=20250918164738
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　KPE　Ｌわたしの幸せな結婚ＰＮ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-kpe0075.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/watashino_kekkon.jpg?t=20250917162355
# 価格    : 38000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　ネット（オーゼキ）　Ｌチバリヨ２ＺＢ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-net0063.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/chibariyo2.jpg?t=20250804152121
# 価格    : 26000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　スパイキー（新日テクノロジー）　Ｌ絶対衝激ＴＫ～PLATONIC HEART～【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-spiky0029.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_zettaishogeki.jpg?t=20250717163353
# 価格    : 39000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　アクロス　Ｌ／ギルティクラウン２／ＸＦ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-across0025.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/giltyclown2.jpg?t=20250717161708
# 価格    : 47000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　エンターライズ（アデリオン）Ｌデビルメイクライ５ＳＴ ＸＡ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-enterrise0035.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_dmc5.jpg?t=20250717160821
# 価格    : 46000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　オーイズミ　ＬＢ１０００ちゃんアルファＬ３【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-o-izumi0034.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_1000chan.jpg?t=20250717154800
# 価格    : 55000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　山佐　 ＬＢニューパルサーＢＴＣ９【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-yamasa0134.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_new_pulsarBT.jpg?t=20250620160913
# 価格    : 40000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　ユニバーサルブロス　  緑ドン VIVA!情熱南米編 REVIVAL（Ｌ／緑ドン５／ＦＹ）【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-univaersal-bros0012.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_midoridon.jpg?t=20250603163539
# 価格    : 39000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　DAXEL　Ｌようこそ実力至上主義の教室へＤＥ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-daxel0017.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/youkoso.jpg?t=20250603161919
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　ビスティ　 Ｌ機動戦士ガンダムＳＥＥＤ　Ｇ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-bisty0053.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/gundam_seed.jpg?t=20250603160330
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　大都技研（サボハニ）　吉宗（Ｌ／ヨシムネＳ／ＳＣ２）【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-daito0086.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/l_yoshimune.jpg?t=20250515154708
# 価格    : 47000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　オリンピア（オリンピアエステート）Ｌ麻雀物語Ｓ２【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-orinpia0098.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/l_mahjangmonogatari.jpg?t=20250515153736
# 価格    : 45000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　山佐　 ＬパチスロアイドルマスターミリオンライブＨＣ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-yamasa0133.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/l_idolmaster.jpg?t=20250515151328
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　Ｄａｉｉｃｈｉ（アイドル）　Ｌうしおととら白面決戦ＶＨ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-daiichi0022.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/l_ushiototora.jpg?t=20250515150212
# 価格    : 39000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　京楽（SUN SUN SUN）　Ｌ仮面ライダー電王ＵＤ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-kyoraku0024.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/rider_deno.jpg?t=20250515144457
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　エンターライズ　Ｌバイオハザード５ＺＥ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-enterrise0034.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/baio_5.jpg?t=20250415155612
# 価格    : 47000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　ビスティ　フィーバー夏祭り【4号機/コイン不要機非対応】
# 商品URL : https://pachislobank.com/SHOP/genjyou0053.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/f_natsumatsuri.jpg?t=20250304121226
# 価格    : 70000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　SANKYO　Ｌありふれた職業で世界最強ｊＡ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-sankyo0062.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/arifureta.jpg?t=20250220153539
# 価格    : 39000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　山佐（セブンリーグ）　 ＬスーパーブラックジャックＳＬＤＣ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-yamasa0132.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/L_super_blackjack.jpg?t=20250220150355
# 価格    : 48000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　藤商事（オレンジ）　Ｌとある魔術の禁書目録　一方通行ＲＺ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-fujisyouji0033.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/toaru_ippoutuko.jpg?t=20250220142156
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　SANKYO　Ｌダンベル何キロ持てる？Ｘ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-sankyo0061.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/danberu.jpg?t=20250220140241
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　パイオニア　Ｓハナハナホウオウ～天翔～ＬＸ
# 商品URL : https://pachislobank.com/SHOP/s-pioneer0023.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/hana_houou_LX.jpg?t=20250220132315
# 価格    : 39000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　ビスティ　 Ｌシン・エヴァンゲリオン【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-bisty0052.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/shineva.jpg?t=20250129163427
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　EXCITE　Ｌスマスロサラリーマン金太郎ＥＴ【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-excite0018.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/l_sarakin.jpg?t=20250129155630
# 価格    : 42000
# [DB] 保存完了
# --------------------------------------------------------------------------------
# ショップ: パチスロ中古実機販売なら【パチスロバンク】
# カテゴリ: slot
# 機種名  : パチスロ実機　平和　Ｌルパン三世大航海者の秘宝Ｈ１【スマスロユニット付き】
# 商品URL : https://pachislobank.com/SHOP/s-heiwa0027.html
# 画像URL : https://image1.shopserve.jp/pachislobank.com/pic-labo/llimg/l_lupin_daikoukaisya.jpg?t=20250129150744
# 価格    : 42000
# [DB] 保存完了
#
# ページ検出件数 : 40
# ページ保存件数 : 40
# [WAIT] 次のページまで10秒待機します
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 591
#     585         if page < MAX_PAGE:
#     586             print(
#     587                 f"[WAIT] 次のページまで"
#     588                 f"{REQUEST_INTERVAL}秒待機します"
#     589             )
# --> 591             time.sleep(
#     592                 REQUEST_INTERVAL
#     593             )
#     596 finally:
#     597
#     598     # ==================
#     599     # 終了
#     600     # ==================
#     602     session.close()
#
# KeyboardInterrupt:
