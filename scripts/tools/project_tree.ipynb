# %%
import os


# 除外するフォルダ
IGNORE_DIRS = {
    "__pycache__",
    ".git",
    ".idea",
    ".vscode",
    ".pytest_cache",
    ".mypy_cache",
}

# プロジェクトルートからの相対パスで除外
IGNORE_PATHS = {
    "output/img/machines",
    "output/machines",
    "output/makers",    
    "static/img/machines"
}


def print_tree(root_path):

    root_path = os.path.abspath(root_path)

    print(os.path.basename(root_path) + "/")

    def _walk(current_path, prefix=""):

        rel_path = os.path.relpath(
            current_path,
            root_path,
        ).replace("\\", "/")

        # 指定パスは中身ごと除外
        if rel_path in IGNORE_PATHS:
            return

        entries = []

        for name in os.listdir(current_path):

            if name.startswith("."):
                continue

            full_path = os.path.join(
                current_path,
                name,
            )

            # __pycache__等は除外
            if (
                os.path.isdir(full_path)
                and name in IGNORE_DIRS
            ):
                continue

            entries.append(name)

        # フォルダ→ファイル順
        entries.sort(
            key=lambda x: (
                not os.path.isdir(
                    os.path.join(current_path, x)
                ),
                x.lower(),
            )
        )

        for i, name in enumerate(entries):

            full_path = os.path.join(
                current_path,
                name,
            )

            is_last = (
                i == len(entries) - 1
            )

            branch = (
                "└── "
                if is_last
                else "├── "
            )

            print(
                prefix + branch + name
            )

            if os.path.isdir(full_path):

                extension = (
                    "    "
                    if is_last
                    else "│   "
                )

                _walk(
                    full_path,
                    prefix + extension,
                )


    _walk(root_path)


# ===========================
# 実行
# ===========================

try:
    base_dir = os.path.dirname(
        os.path.abspath(__file__)
    )
except NameError:
    base_dir = os.getcwd()

project_root = os.path.abspath(
    os.path.join(
        base_dir,
        "..",
        "..",
    )
)

print_tree(project_root)
# Out:
# soubanavi/
# ├── credentials
# │   ├── cookies.json
# │   ├── gspread-test-402206-686fe226262e.json
# │   └── sedoinfinity.key
# ├── db
# │   ├── columns_machine_master.txt
# │   ├── columns_price_history.txt
# │   ├── columns_product_summary.txt
# │   ├── columns_with_type.txt
# │   └── data.db
# ├── output
# │   ├── css
# │   │   ├── common.css
# │   │   ├── index.css
# │   │   ├── layout.css
# │   │   ├── machine_detail.css
# │   │   ├── machine_index.css
# │   │   ├── maker_detail.css
# │   │   ├── maker_index.css
# │   │   ├── price_down_today_detail.css
# │   │   ├── price_down_today_index.css
# │   │   ├── price_range_detail.css
# │   │   ├── price_range_index.css
# │   │   ├── ranking_index.css
# │   │   ├── ranking_low_price_index.css
# │   │   ├── recent_machines.css
# │   │   └── sidebar.css
# │   ├── favorites
# │   │   └── index.html
# │   ├── history
# │   │   └── index.html
# │   ├── img
# │   │   ├── machines
# │   │   ├── header-desktop.png
# │   │   ├── header-mobile.png
# │   │   └── no_image.webp
# │   ├── js
# │   │   ├── common.js
# │   │   ├── machine_detail.js
# │   │   └── machine_index.js
# │   ├── machines
# │   ├── makers
# │   ├── price-down-today
# │   │   ├── pachinko
# │   │   │   └── index.html
# │   │   ├── slot
# │   │   │   └── index.html
# │   │   └── index.html
# │   ├── price-range
# │   │   ├── 10000-19999
# │   │   │   └── index.html
# │   │   ├── 100000-199999
# │   │   │   └── index.html
# │   │   ├── 20000-29999
# │   │   │   └── index.html
# │   │   ├── 200000-499999
# │   │   │   └── index.html
# │   │   ├── 30000-39999
# │   │   │   └── index.html
# │   │   ├── 40000-59999
# │   │   │   └── index.html
# │   │   ├── 500000-over
# │   │   │   └── index.html
# │   │   ├── 60000-99999
# │   │   │   └── index.html
# │   │   └── index.html
# │   ├── rankings
# │   │   ├── low-price
# │   │   │   ├── pachinko
# │   │   │   │   └── index.html
# │   │   │   ├── slot
# │   │   │   │   └── index.html
# │   │   │   └── index.html
# │   │   └── index.html
# │   ├── recent-machines
# │   │   └── index.html
# │   ├── apple-touch-icon.png
# │   ├── favicon-192x192.png
# │   ├── favicon-48x48.png
# │   ├── favicon-512x512.png
# │   ├── favicon-96x96.png
# │   ├── favicon.ico
# │   ├── index.html
# │   ├── robots.txt
# │   ├── site.webmanifest
# │   └── sitemap.xml
# ├── scripts
# │   ├── database
# │   │   ├── match-p.ipynb
# │   │   ├── match-p.py
# │   │   ├── match-s.ipynb
# │   │   ├── match-s.py
# │   │   ├── normalize-p.ipynb
# │   │   ├── normalize-p.py
# │   │   ├── normalize-s.ipynb
# │   │   ├── normalize-s.py
# │   │   ├── sync_machine_master.ipynb
# │   │   ├── sync_machine_master.py
# │   │   ├── update_price_history.ipynb
# │   │   ├── update_price_history.py
# │   │   ├── update_product_summary.ipynb
# │   │   └── update_product_summary.py
# │   ├── database_tools
# │   │   ├── backfill_price_history.ipynb
# │   │   ├── create_machine_master.ipynb
# │   │   ├── create_product_summary.ipynb
# │   │   ├── create_result_table.ipynb
# │   │   └── migrate_database.ipynb
# │   ├── generate
# │   │   ├── index.ipynb
# │   │   ├── index.py
# │   │   ├── machine_detail.ipynb
# │   │   ├── machine_detail.py
# │   │   ├── machine_index.ipynb
# │   │   ├── machine_index.py
# │   │   ├── maker_pages.ipynb
# │   │   ├── maker_pages.py
# │   │   ├── price_down_today_pages.ipynb
# │   │   ├── price_down_today_pages.py
# │   │   ├── price_range_pages.ipynb
# │   │   ├── price_range_pages.py
# │   │   ├── ranking_index.ipynb
# │   │   ├── ranking_index.py
# │   │   ├── ranking_low_price_pages.ipynb
# │   │   ├── ranking_low_price_pages.py
# │   │   ├── recent_machines.ipynb
# │   │   ├── recent_machines.py
# │   │   ├── sitemap.ipynb
# │   │   ├── sitemap.py
# │   │   ├── user_pages.ipynb
# │   │   └── user_pages.py
# │   ├── mail
# │   │   ├── mail.ipynb
# │   │   └── mail.py
# │   ├── scraping
# │   │   ├── a-pachi-p.ipynb
# │   │   ├── a-pachi-p.py
# │   │   ├── aslot-s.ipynb
# │   │   ├── aslot-s.py
# │   │   ├── bank-s.ipynb
# │   │   ├── bank-s.py
# │   │   ├── home-p.ipynb
# │   │   ├── home-p.py
# │   │   ├── home-s.ipynb
# │   │   ├── home-s.py
# │   │   ├── nakaiti-p.ipynb
# │   │   ├── nakaiti-p.py
# │   │   ├── nakaiti-s.ipynb
# │   │   ├── nakaiti-s.py
# │   │   ├── wasshoi-s.ipynb
# │   │   └── wasshoi-s.py
# │   ├── tools
# │   │   ├── convert_ipynb.ipynb
# │   │   ├── download_machine_images_p.ipynb
# │   │   ├── download_machine_images_s.ipynb
# │   │   ├── list_ipynb.ipynb
# │   │   ├── project_tree.ipynb
# │   │   ├── reload_utils.ipynb
# │   │   └── scripts_all_py変換.ipynb
# │   ├── upload
# │   │   ├── upload_output.ipynb
# │   │   └── upload_output.py
# │   ├── run_all.ipynb
# │   └── run_all.py
# ├── static
# │   ├── css
# │   │   ├── common.css
# │   │   ├── index.css
# │   │   ├── layout.css
# │   │   ├── machine_detail.css
# │   │   ├── machine_index.css
# │   │   ├── maker_detail.css
# │   │   ├── maker_index.css
# │   │   ├── price_down_today_detail.css
# │   │   ├── price_down_today_index.css
# │   │   ├── price_range_detail.css
# │   │   ├── price_range_index.css
# │   │   ├── ranking_index.css
# │   │   ├── ranking_low_price_index.css
# │   │   ├── recent_machines.css
# │   │   └── sidebar.css
# │   ├── img
# │   │   ├── machines
# │   │   ├── header-desktop.png
# │   │   ├── header-mobile.png
# │   │   └── no_image.webp
# │   ├── js
# │   │   ├── common.js
# │   │   ├── machine_detail.js
# │   │   └── machine_index.js
# │   ├── apple-touch-icon.png
# │   ├── favicon-192x192.png
# │   ├── favicon-48x48.png
# │   ├── favicon-512x512.png
# │   ├── favicon-96x96.png
# │   ├── favicon.ico
# │   ├── robots.txt
# │   └── site.webmanifest
# ├── templates
# │   ├── includes
# │   │   ├── top
# │   │   │   ├── highest_price_ranking_section.html
# │   │   │   ├── keyword_section.html
# │   │   │   ├── lowest_price_ranking_section.html
# │   │   │   ├── quick_menu_section.html
# │   │   │   ├── recent_machines_section.html
# │   │   │   ├── today_price_drop_section.html
# │   │   │   └── top_guide_section.html
# │   │   ├── breadcrumb.html
# │   │   ├── footer.html
# │   │   ├── header.html
# │   │   ├── share_buttons.html
# │   │   ├── sidebar.html
# │   │   └── site_search.html
# │   ├── machines
# │   │   ├── machine_detail.html
# │   │   ├── machine_index.html
# │   │   └── recent_machines.html
# │   ├── makers
# │   │   ├── maker_detail.html
# │   │   └── maker_index.html
# │   ├── pages
# │   │   ├── privacy.html
# │   │   └── terms.html
# │   ├── price_down_today
# │   │   ├── price_down_today_detail.html
# │   │   └── price_down_today_index.html
# │   ├── price_range
# │   │   ├── price_range_detail.html
# │   │   └── price_range_index.html
# │   ├── rankings
# │   │   ├── ranking_index.html
# │   │   └── ranking_low_price_index.html
# │   ├── user
# │   │   ├── favorites.html
# │   │   └── history.html
# │   ├── 404.html
# │   ├── base.html
# │   └── index.html
# ├── upload
# └── utils
#     ├── __init__.py
#     ├── breadcrumb_utils.py
#     ├── config.py
#     ├── db_utils.py
#     ├── maker_utils.py
#     ├── page_utils.py
#     ├── seo.py
#     └── static_utils.py
