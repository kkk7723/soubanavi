# %%
from pathlib import Path

scripts_dir = Path.cwd().parent

for notebook in sorted(scripts_dir.rglob("*.ipynb")):
    if ".ipynb_checkpoints" in notebook.parts:
        continue
    print(notebook)
# Out:
# C:\Users\Owner\myenv310\soubanavi\scripts\database\backfill_price_history.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\db作成product_summary.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\db作成result_table.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\db移行.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\match-p.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\match-s.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\normalize-p.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\normalize-s.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\update_price_history.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\database\集計テーブル.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\generate\index_page.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\generate\machine_list_page.ipynb
# C:\Users\Owner\myenv310\soubanavi\scripts\generate\machine_pages.ipynb
# ...
